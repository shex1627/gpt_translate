# %%
# %load_ext autoreload
# %autoreload 2

# %%
from gpt_translate.articles.JsonArticleManager import JsonArticleManager
from gpt_translate.crawl.util import extract_info, scroll_one_step, normalize_date
import pandas as pd

# %%
ARTICLE_JSON_PATH = "/opt/shichenh/articles_embedding.json"
article_manager = JsonArticleManager(ARTICLE_JSON_PATH)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 ARTICLE_JSON_PATH = "/opt/shichenh/articles_embedding.json"
# ----> 2 article_manager = JsonArticleManager(ARTICLE_JSON_PATH)
#
# File ~/code/gpt_translate/src/gpt_translate/articles/JsonArticleManager.py:21, in JsonArticleManager.__init__(self, articles_json_path)
#      19 def __init__(self, articles_json_path: str):
#      20     #articles_json = load_json_files(json_data_path)
# ---> 21     self.articles_df = pd.read_json(articles_json_path, orient="records")
#      22     # convert chinese tags to dictionary if it is string
#      23     self.articles_df['chinese_tags'] = self.articles_df['chinese_tags'].apply(lambda x: eval(x) if isinstance(x, str) else x)
#
# File ~/.pyenv/versions/gpt-translate/lib/python3.11/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/.pyenv/versions/gpt-translate/lib/python3.11/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/.pyenv/versions/gpt-translate/lib/python3.11/site-packages/pandas/io/json/_json.py:733, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options)
#     730 if convert_axes is None and orient != "table":
#     731     convert_axes = True
# --> 733 json_reader = JsonReader(
#     734     path_or_buf,
#     735     orient=orient,
#     736     typ=typ,
#     737     dtype=dtype,
#     738     convert_axes=convert_axes,
#     739     convert_dates=convert_dates,
#     740     keep_default_dates=keep_default_dates,
#     741     numpy=numpy,
#     742     precise_float=precise_float,
#     743     date_unit=date_unit,
#     744     encoding=encoding,
#     745     lines=lines,
#     746     chunksize=chunksize,
#     747     compression=compression,
#     748     nrows=nrows,
#     749     storage_options=storage_options,
#     750     encoding_errors=encoding_errors,
#     751 )
#     753 if chunksize:
#     754     return json_reader
#
# File ~/.pyenv/versions/gpt-translate/lib/python3.11/site-packages/pandas/io/json/_json.py:818, in JsonReader.__init__(self, filepath_or_buffer, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression, nrows, storage_options, encoding_errors)
#     815     if not self.lines:
#     816         raise ValueError("nrows can only be passed if lines=True")
# --> 818 data = self._get_data_from_filepath(filepath_or_buffer)
#     819 self.data = self._preprocess_data(data)
#
# File ~/.pyenv/versions/gpt-translate/lib/python3.11/site-packages/pandas/io/json/_json.py:874, in JsonReader._get_data_from_filepath(self, filepath_or_buffer)
#     866     filepath_or_buffer = self.handles.handle
#     867 elif (
#     868     isinstance(filepath_or_buffer, str)
#     869     and filepath_or_buffer.lower().endswith(
#    (...)
#     872     and not file_exists(filepath_or_buffer)
#     873 ):
# --> 874     raise FileNotFoundError(f"File {filepath_or_buffer} does not exist")
#     876 return filepath_or_buffer
#
# FileNotFoundError: File /opt/shichenh/articles_embedding.json does not exist

# %%
article_manager.articles_df.shape
# Out:
# (1582, 17)

# %%
LOG_FILE_PATH = os.environ.get("LOG_FILE_PATH", "/home/bookworm/blogger_crawl.log")
ARTICLE_JSON_PATH = os.environ.get("ARTICLE_JSON_PATH", "/home/bookworm/code/gpt_translate/data/articles_embedding.json")

# %%
article_manager.articles_df.sort_values("id", ascending=False).head()
# Out:
#                         title       date  \
# 1581          该吃吃该喝喝，省吃俭用能干啥？ 2023-05-22
# 1580            牛羊才会成群，猛兽从来独处 2100-01-01
# 1579  从这个月薪八万炫富停职的90后来看工资保密制度 2100-01-01
# 1578        就算“司机”是山中鹿之介，又如何？ 2100-01-01
# 1577         韦神的师兄告诉你，庙里也是个江湖 2100-01-01
#
#                                                     url  is_original  \
# 1581  https://c.m.163.com/news/a/I5B5KTO20553JMK2.ht...          NaN
# 1580  https://c.m.163.com/news/a/ID3MGDG70553JMK2.ht...          NaN
# 1579  https://c.m.163.com/news/a/HDJ6J8JJ0553JMK2.ht...          NaN
# 1578  https://c.m.163.com/news/a/HHCFNR8H0553JMK2.ht...          NaN
# 1577  https://c.m.163.com/news/a/HIEUDO0A0553JMK2.ht...          NaN
#
#                                                    text  text_len  \
# 1581  很多人看了中产分化那一期，很焦虑\n如果化解不了内心的焦虑，我建议你看看罗马那一期\n每个人...       NaN
# 1580  文章来自微信公众号：记忆承载，请关注阅读全文\n昨天看了你要知道自己想干嘛\n有读者问我，怎...       NaN
# 1579  文章来自微信公众号：记忆承载\n欢迎关注阅读全文\n有人让我聊，继坑爹坑大伯三伯坑全家之后的...       NaN
# 1578  文章来自微信公众号：记忆承载\n欢迎关注阅读全文\n昨天如预料之中，挨骂了\n我说那啥司机，...       NaN
# 1577  文章来自微信公众号：记忆承载\n欢迎关注阅读全文\n我们聊过还俗的法师，轻生的律师\n这位还...       NaN
#
#                                             translation  \
# 1581  Many people watched the episode about the diff...
# 1580  The article is from the WeChat public account:...
# 1579  The article is from the WeChat public account:...
# 1578  The article is from the WeChat public account:...
# 1577  The article is from the WeChat public account:...
#
#                                            english_tags  \
# 1581  {'Investment': 10, 'Lifestyle': 8, 'Happiness'...
# 1580  {'Self-Reflection': 10, 'Individuality': 9, 'C...
# 1579  {'Workplace Dynamics': 10, 'High Salaries': 9,...
# 1578  {'Japanese Warring States period': 10, 'Shikan...
# 1577  {'Monastic Life': 10, 'Liu Zhiyu': 10, 'Religi...
#
#                                            chinese_tags    english_main_topic  \
# 1581  {'投资': 10, '生活方式': 8, '幸福': 7, '房地产': 7, '社会压力...  Investment Mentality
# 1580  {'自我反思': 10, '个性': 9, '从众': 9, '个人成长': 8, '社会'...       Self-Reflection
# 1579  {'职场动态': 10, '高薪': 9, '保密': 8, '金融行业': 7, '职业建...             Workplace
# 1578  {'日本战国时代': 10, '山中鹿之助': 10, '尼子氏': 10, '豐臣秀吉':...      Japanese History
# 1577  {'出家生活': 10, '刘志宇': 10, '宗教': 8, '社会': 7, '期望'...         Monastic Life
#
#      chinese_main_topic  media_ct  chinese_text_len  \
# 1581               投资心态       NaN               NaN
# 1580               自我反思       NaN               NaN
# 1579                 职场       NaN               NaN
# 1578               日本历史       NaN               NaN
# 1577               出家生活       NaN               NaN
#
#                                        pre_embed_tokens  \
# 1581  Investment_Mentality Investment Lifestyle Happ...
# 1580  Self-Reflection Self-Reflection Individuality ...
# 1579  Workplace Workplace_Dynamics High_Salaries Con...
# 1578  Japanese_History Japanese_Warring_States_perio...
# 1577  Monastic_Life Monastic_Life Liu_Zhiyu Religion...
#
#                                               embedding    id  \
# 1581  [0.0014230934, -0.0055142688, 0.03098327480000...  1581
# 1580  [-0.0067068571000000006, 0.0002320712000000000...  1580
# 1579  [0.0009163383, -0.0081531061, 0.0110882251, -0...  1579
# 1578  [-0.0199379083, -0.013216516900000001, 0.00947...  1578
# 1577  [0.012389468, 0.0045265183, 0.0073220013, -0.0...  1577
#
#                                           english_title
# 1581  Eat and Drink as You Should, What Can You Do b...
# 1580  Cattle and Sheep Gather in Herds, Predators Al...
# 1579  Looking at the Salary Confidentiality System f...
# 1578   So What If the 'Driver' is Shanzhong Lu Zhi Jie?
# 1577  Master Wei's Senior Brother Tells You, The Tem...
